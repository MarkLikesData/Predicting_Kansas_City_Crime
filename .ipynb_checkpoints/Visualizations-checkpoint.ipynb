# %%
import pandas as pd
pd.options.display.max_columns = 100
from matplotlib import pyplot as plt
import numpy as np

import seaborn as sns
import os

# %%
file = os.path.join('kc_crime_for_visualizations.csv')
data = pd.read_csv(file)

# %%
data.head(1)
# Out:
#          Date  Hour            Crime    Zip Race Sex   Age Firearm   Latitude  \
# 0  2017-05-28     3  Stolen_Property  64111    W   F  29.0       N  39.053635
#
#    Longitude
# 0 -94.595998

# %%
data['Male'] = pd.Series(np.where(data.Sex.values == 'M', 1, 0), data.index)
# data['Female'] = pd.Series(np.where(data.Sex.values == 'Female', 1, 0), data.index)

# %%
data.head(1)
# Out:
#          Date  Hour            Crime    Zip Race Sex   Age Firearm   Latitude  \
# 0  2017-05-28     3  Stolen_Property  64111    W   F  29.0       N  39.053635
#
#    Longitude  Male
# 0 -94.595998     0

# %%
data['Female'] = 1 - data['Male']
data.groupby('Race').agg('mean')[['Male', 'Female']].plot(kind='bar', stacked=True, color=['b', 'r']);
plt.show()

# %%
fig = plt.figure(figsize=(25, 12))
sns.violinplot(x='Race', y='Age', 
               hue='Male', data=data, 
               split=True,
               palette={0: "r", 1: "b"}
              );
plt.show()

# %%
figure = plt.figure(figsize=(25, 12))
plt.hist([data[data['Male'] == 1]['Age'], data[data['Male'] == 0]['Age']], 
         stacked=True, color = ['b','r'],
         bins = 50, label = ['Male','Female'])
plt.xlabel('Age')
plt.ylabel('I Have no idea')
plt.legend();
plt.show()
# Out:
# C:\Users\Mark\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
data.head(1)
# Out:
#          Date  Hour            Crime    Zip Race Sex   Age Firearm   Latitude  \
# 0  2017-05-28     3  Stolen_Property  64111    W   F  29.0       N  39.053635
#
#    Longitude  Male  Female
# 0 -94.595998     0       1

# %%
data.dtypes
# Out:
# Date          object
# Hour           int64
# Crime         object
# Zip            int64
# Race          object
# Sex           object
# Age          float64
# Firearm       object
# Latitude     float64
# Longitude    float64
# Male           int32
# Female         int32
# dtype: object

# %%
plt.figure(figsize=(25, 12))
ax = plt.subplot()

ax.scatter(data[data['Male'] == 1]['Race'], data[data['Male'] == 1]['Age'], 
           c='blue', s=data[data['Male'] == 1]['Age'])
ax.scatter(data[data['Male'] == 0]['Race'], data[data['Male'] == 0]['Age'], 
           c='red', s=data[data['Male'] == 0]['Age']);
plt.show()

# %%
data.head(1)
# Out:
#          Date  Hour            Crime    Zip Race Sex   Age Firearm   Latitude  \
# 0  2017-05-28     3  Stolen_Property  64111    W   F  29.0       N  39.053635
#
#    Longitude  Male  Female
# 0 -94.595998     0       1

# %%
ax = plt.subplot()
ax.set_ylabel('Age')
data.groupby('Race').mean()['Age'].plot(kind='bar', figsize=(10, 7), ax = ax);
plt.show()

# %%
ax = plt.subplot()
ax.set_ylabel('Age')
data.groupby('Sex').mean()['Age'].plot(kind='bar', figsize=(10, 7), ax = ax);
plt.show()

# %%
data.head(1)
# Out:
#          Date  Hour            Crime    Zip Race Sex   Age Firearm   Latitude  \
# 0  2017-05-28     3  Stolen_Property  64111    W   F  29.0       N  39.053635
#
#    Longitude  Male  Female
# 0 -94.595998     0       1

# %%
fig = plt.figure(figsize=(25, 20))
sns.violinplot(x='Race', y='Age', hue='Male', data=data, split=True, palette={0: "r", 1: "b"});
plt.show()

# %%
data.head(1)
# Out:
#          Date  Hour            Crime    Zip Race Sex   Age Firearm   Latitude  \
# 0  2017-05-28     3  Stolen_Property  64111    W   F  29.0       N  39.053635
#
#    Longitude  Male  Female
# 0 -94.595998     0       1
