# %% [markdown]
# # Machine Learning Project
# # Kansas City Crime Data Deep Dive

# %% [markdown]
# ### Import Dependancies

# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ### Getting our KCMO crime data (Raw data came from data.kcmo.org)

# %%
file_name = os.path.join('Resources', 'KCPD_Crime_Data_2017.csv')
kc_crime = pd.read_csv(file_name)
kc_crime.reset_index()
kc_crime.head(2)
# Out:
#    Report_No Reported_Date Reported_Time   From_Date From_Time To_Date  \
# 0  100080848     5/28/2017          3:44   5/28/2017      2:00     NaN
# 1  120046817    11/21/2017         13:30  11/20/2017      9:00     NaN
#
#   To_Time  Offense IBRS           Description  \
# 0     NaN     1352  280  Stolen Property OFFE
# 1     NaN      101  09A  HOMICIDE/Non Neglige
#
#                          ...                          Rep_Dist Area DVFlag  \
# 0                        ...                            PJ3255  CPD      U
# 1                        ...                            PJ1029  CPD      U
#
#    Invl_No Involvement Race Sex   Age Firearm Used Flag  \
# 0        1         VIC    W   F  29.0                 N
# 1        1         SUS    B   M   NaN                 Y
#
#                                             Location
# 0  4000 MILL ST\nKANSAS CITY 64111\n(39.053635, -...
# 1  1100 LOCUST ST\nKANSAS CITY 64105\n(39.10091, ...
#
# [2 rows x 24 columns]

# %% [markdown]
# ### Filter for male and female victims in KCMO

# %%
# kc_crime1 = kc_crime[kc_crime.City.str.contains("KANSAS CITY") == True]
# kc_crime2 = kc_crime1[kc_crime1.Involvement.str.contains("VIC") == True]
# kc_crime3 = kc_crime2[kc_crime2.Sex.str.contains("NaN") == False]
# kc_crime4 = kc_crime3[kc_crime3.Sex.str.contains("U") == False]
kc_crime4b = kc_crime4[kc_crime4.Zip_Code.str.contains("99999") == False]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8b9b3b3c1d03> in <module>()
#       3 # kc_crime3 = kc_crime2[kc_crime2.Sex.str.contains("NaN") == False]
#       4 # kc_crime4 = kc_crime3[kc_crime3.Sex.str.contains("U") == False]
# ----> 5 kc_crime4b = kc_crime4[kc_crime4.Zip_Code.str.contains("99999") == False]
#
# NameError: name 'kc_crime4' is not defined

# %% [markdown]
# ### Drop unnecessary columns

# %%
kc_crime5 = kc_crime4b.drop(['To_Date', 'From_Date', 'To_Time', 'From_Time',
                          'Offense', 'IBRS', 'Rep_Dist', 'Area', 'Beat' ], axis=1)

# %% [markdown]
# ### Remove abnormal age values

# %%
kc_crime6 = kc_crime5[kc_crime5['Age'] < 91]

# %%
kc_crime6.count()
# Out:
# Report_No            43908
# Reported_Date        43908
# Reported_Time        43908
# Description          43908
# Address              43908
# City                 43908
# Zip Code             43908
# DVFlag               43908
# Invl_No              43908
# Involvement          43908
# Race                 43908
# Sex                  43908
# Age                  43908
# Firearm Used Flag    43908
# Location             43908
# dtype: int64

# %% [markdown]
# ### Parse out latitude and longitude

# %%
kc_crime6_copy = kc_crime6.copy()

# %%
#copy the dataframe to a work df
# acc_drugtemp_df = acc_drug_deaths_df.copy()

# %%
kc_crime6_copy.head(2)
# Out:
#    Report_No Reported_Date Reported_Time           Description  \
# 0  100080848     5/28/2017          3:44  Stolen Property OFFE
# 2  120046817    11/21/2017         13:30  HOMICIDE/Non Neglige
#
#            Address         City  Zip Code DVFlag  Invl_No Involvement Race  \
# 0    4000  MILL ST  KANSAS CITY     64111      U        1         VIC    W
# 2  1100  LOCUST ST  KANSAS CITY     64105      N        1         VIC    B
#
#   Sex   Age Firearm Used Flag  \
# 0   F  29.0                 N
# 2   F  69.0                 Y
#
#                                             Location
# 0  4000 MILL ST\nKANSAS CITY 64111\n(39.053635, -...
# 2  1100 LOCUST ST\nKANSAS CITY 64105\n(39.10091, ...

# %%
#split the DeathLoc column into two columns 
# acc_drugtemp3_df = acc_drugtemp_df['DeathLoc'].str[2:-1].str.split('\n', expand=True)

# %%
kc_crime7 = kc_crime6_copy['Location'].str[2:-1].str.split('\n', expand=True)

# %%
kc_crime7.head(2)
# Out:
#               0                  1                       2
# 0    00 MILL ST  KANSAS CITY 64111  (39.053635, -94.595998
# 2  00 LOCUST ST  KANSAS CITY 64105   (39.10091, -94.577328

# %%
test = kc_crime7[2][0]
test
# Out:
# '(39.053635, -94.595998'

# %%
#create a column called geo getting rid of the left (
# acc_drugtemp3_df['Geo'] = acc_drugtemp3_df[1][1][1:-1]
kc_crime7['Geo'] = kc_crime7[2][0:][0:]

# %%
kc_crime7.head(2)
# Out:
#               0                  1                       2  \
# 0    00 MILL ST  KANSAS CITY 64111  (39.053635, -94.595998
# 2  00 LOCUST ST  KANSAS CITY 64105   (39.10091, -94.577328
#
#                       Geo
# 0  (39.053635, -94.595998
# 2   (39.10091, -94.577328

# %%
kc_crime7['Geo'] = kc_crime7['Geo'].str[1:]

# %%
kc_crime7.head(2)
# Out:
#               0                  1                       2  \
# 0    00 MILL ST  KANSAS CITY 64111  (39.053635, -94.595998
# 2  00 LOCUST ST  KANSAS CITY 64105   (39.10091, -94.577328
#
#                      Geo
# 0  39.053635, -94.595998
# 2   39.10091, -94.577328

# %%
kc_crime8 = kc_crime7['Geo'].str[0:].str.split(',', expand=True)
kc_crime8.head(2)
# Out:
#            0            1
# 0  39.053635   -94.595998
# 2   39.10091   -94.577328

# %%
kc_crime8['Lat'] = kc_crime8[0]
kc_crime8['Lon'] = kc_crime8[1]
kc_crime8 = kc_crime8.drop([0], axis=1)
kc_crime8 = kc_crime8.drop([1], axis=1)
kc_crime8.head()
# Out:
#           Lat          Lon
# 0   39.053635   -94.595998
# 2    39.10091   -94.577328
# 33   39.17744   -94.572069
# 36  39.033505   -94.547812
# 46       None         None

# %%
kc_crime9 = kc_crime6.append(kc_crime8, ignore_index=True)

# %%
kc_crime9.head(20)
# Out:
#                         Address   Age         City DVFlag  \
# 0                 4000  MILL ST  29.0  KANSAS CITY      U
# 1               1100  LOCUST ST  69.0  KANSAS CITY      N
# 2             4600  N HOLMES ST  31.0  KANSAS CITY      U
# 3        E 51 ST and WALROND AV  19.0  KANSAS CITY      U
# 4               3400  PALMER AV  36.0  KANSAS CITY      U
# 5                9400  NE 79 ST  62.0  KANSAS CITY      U
# 6       E 41 ST and PROSPECT AV  70.0  KANSAS CITY      U
# 7               1100  LOCUST ST  35.0  KANSAS CITY      U
# 8       E MISSOURI AV and PASEO  26.0  KANSAS CITY      U
# 9       E 8 ST and VAN BRUNT BL  25.0  KANSAS CITY      U
# 10     CHESTNUT AV and SWOPE PK  21.0  KANSAS CITY      U
# 11     CHESTNUT AV and SWOPE PK  21.0  KANSAS CITY      U
# 12              1100  LOCUST ST  36.0  KANSAS CITY      U
# 13              1100  LOCUST ST  18.0  KANSAS CITY      U
# 14           1600  NE PARVIN RD  28.0  KANSAS CITY      U
# 15  COLLEGE AV and E GREGORY BL  52.0  KANSAS CITY      U
# 16           1200  E LINWOOD BL  24.0  KANSAS CITY      N
# 17           1200  E LINWOOD BL  21.0  KANSAS CITY      N
# 18                 5200  E 6 ST  37.0  KANSAS CITY      Y
# 19            900  BALTIMORE AV  45.0  KANSAS CITY      U
#
#              Description Firearm Used Flag  Invl_No Involvement  Lat  \
# 0   Stolen Property OFFE                 N      1.0         VIC  NaN
# 1   HOMICIDE/Non Neglige                 Y      1.0         VIC  NaN
# 2             Auto Theft                 N      1.0         VIC  NaN
# 3           Intimidation                 N      1.0         VIC  NaN
# 4   Agg Assault - Domest                 N      1.0         VIC  NaN
# 5             Auto Theft                 N      1.0         VIC  NaN
# 6   Possession/Sale/Dist                 N      1.0         VIC  NaN
# 7   HOMICIDE/Non Neglige                 N      1.0         VIC  NaN
# 8   Stolen Property OFFE                 N      1.0         VIC  NaN
# 9   Justifiable Homicide                 Y      1.0         VIC  NaN
# 10  Possession/Sale/Dist                 N      1.0         VIC  NaN
# 11  Stolen Property OFFE                 N      1.0         VIC  NaN
# 12       Forcible Sodomy                 N      1.0         VIC  NaN
# 13                  Rape                 N      1.0         VIC  NaN
# 14  Stolen Property OFFE                 N      1.0         VIC  NaN
# 15  HOMICIDE/Non Neglige                 Y      1.0         VIC  NaN
# 16         Armed Robbery                 Y      1.0         VIC  NaN
# 17         Armed Robbery                 Y      2.0         VIC  NaN
# 18  Non Agg Assault Dome                 N      1.0         VIC  NaN
# 19       Property Damage                 N      1.0         VIC  NaN
#
#                                              Location  Lon Race    Report_No  \
# 0   4000 MILL ST\nKANSAS CITY 64111\n(39.053635, -...  NaN    W  100080848.0
# 1   1100 LOCUST ST\nKANSAS CITY 64105\n(39.10091, ...  NaN    B  120046817.0
# 2   4600 N HOLMES ST\nKANSAS CITY 64119\n(39.17744...  NaN    W  160028258.0
# 3   51 ST and WALROND AV\nKANSAS CITY 64130\n(39.0...  NaN    W  160034107.0
# 4                 3400 PALMER AV\nKANSAS CITY 64138\n  NaN    B  160047600.0
# 5   9400 NE 79 ST\nKANSAS CITY 64157\n(39.235881, ...  NaN    W  160063139.0
# 6   41 ST and PROSPECT AV\nKANSAS CITY 64131\n(39....  NaN    B  160065976.0
# 7   1100 LOCUST ST\nKANSAS CITY 64106\n(39.10091, ...  NaN    W  160069964.0
# 8                  E MISSOURI AV\nKANSAS CITY 64106\n  NaN    B  160077054.0
# 9          8 ST\nand VAN BRUNT BL KANSAS CITY 99999\n  NaN    B  160090081.0
# 10                   CHESTNUT AV\nKANSAS CITY 64132\n  NaN    B  160096118.0
# 11                   CHESTNUT AV\nKANSAS CITY 64132\n  NaN    B  160096118.0
# 12  1100 LOCUST ST\nKANSAS CITY 64106\n(39.10091, ...  NaN    W  160096411.0
# 13  1100 LOCUST ST\nKANSAS CITY 64106\n(39.10091, ...  NaN    W  160097341.0
# 14             1600 NE PARVIN RD\nKANSAS CITY 64117\n  NaN    B  160097564.0
# 15               E COLLEGE AV\nBL KANSAS CITY 99999\n  NaN    B  160097861.0
# 16  1200 E LINWOOD\nBL KANSAS CITY 64109\n(39.0686...  NaN    W  160098019.0
# 17  1200 E LINWOOD\nBL KANSAS CITY 64109\n(39.0686...  NaN    W  160098019.0
# 18  5200 E 6 ST\nKANSAS CITY 64124\n(39.104339, -9...  NaN    W  170000003.0
# 19  900 BALTIMORE AV\nKANSAS CITY 64106\n(39.10334...  NaN    W  170000004.0
#
#    Reported_Date Reported_Time Sex  Zip Code
# 0      5/28/2017          3:44   F   64111.0
# 1     11/21/2017         13:30   F   64105.0
# 2       8/2/2017         13:50   F   64119.0
# 3      8/24/2017         16:22   F   64130.0
# 4      6/28/2017         12:00   F   64138.0
# 5      3/15/2017         14:06   F   64157.0
# 6       4/1/2017         19:21   F   64131.0
# 7       2/4/2017         13:41   M   64106.0
# 8      5/24/2017         14:44   M   64106.0
# 9       3/6/2017         10:52   M   99999.0
# 10     5/20/2017         22:15   M   64132.0
# 11     5/20/2017         22:15   M   64132.0
# 12     9/29/2017         12:30   M   64106.0
# 13     9/29/2017         13:03   F   64106.0
# 14      1/6/2017         15:44   M   64117.0
# 15      1/4/2017          9:32   M   99999.0
# 16      1/3/2017         14:15   M   64109.0
# 17      1/3/2017         14:15   F   64109.0
# 18      1/1/2017          0:16   F   64124.0
# 19      1/1/2017          0:18   M   64106.0

# %%
# test = acc_drugtemp4_df['Coord'][0]
# test.split(',')[1]
test = kc_crime7['Geo'][0]
test.split(',')[0]
# Out:
# '39.053635'

# %%
kc_crime8 = kc_crime7['Geo'].str[0:].str.split(',', expand=True)

# %%
#Add a new column to the dataframe with the latitude and longitude
# acc_drugtemp4_df = acc_drugtemp_df.assign(Coord = acc_drugtemp3_df[1][:-1][0:-1])
kc_crime8 = kc_crime6_copy.assign(Coord = kc_crime7[2][:-1][0:-1])

# %%
#create a column called geo
# acc_drugtemp3b_df['Lat'] = acc_drugtemp3_df[1][1][1:-1]
kc_crime8['Geo'] = kc_crime7[2][:-1][0:-1]

# %%
# test = acc_drugtemp4_df['Coord'][0]
# test.split(',')[1]
test = kc_crime8['Geo'][0]
test.split(',')[1]
# Out:
# ' -94.57732'

# %%
# split the Coord column into two at the ,
# acc_drugtemp5_df = acc_drugtemp4_df['Coord'].str[1:].str.split(',', expand=True)
kc_crime9 = kc_crime8['Geo'].str[0:].str.split(',', expand=True)

# %%
#create a column called geo
# acc_drugtemp3_df['Lat'] = acc_drugtemp5_df[0][:-1][0:-1]
kc_crime8['Latitude'] = kc_crime9[0][:-1][0:-1]
kc_crime8['Longitude'] = kc_crime9[1][:-1][0:-1]

# %%
kc_crime9 =  kc_crime8.drop(['Location', 'Coord', 'Geo'], axis=1)
kc_crime9.head(1)
# Out:
#    Report_No Reported_Date Reported_Time           Description        Address  \
# 0  100080848     5/28/2017          3:44  Stolen Property OFFE  4000  MILL ST
#
#           City  Zip Code DVFlag  Invl_No Involvement Race Sex   Age  \
# 0  KANSAS CITY     64111      U        1         VIC    W   F  29.0
#
#   Firearm Used Flag  Latitude   Longitude
# 0                 N  39.10091   -94.57732

# %% [markdown]
# ### Label encode description

# %%
Description_columns = pd.get_dummies(kc_crime['Description'],prefix = "Description")
kc_crime = pd.concat([kc_crime, Description_columns], axis=1)
kc_crime.drop('Description', axis=1, inplace=True)
